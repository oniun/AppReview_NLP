# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import time
from selenium import webdriver
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# # Connect DB in EC2

# %%
host_name = 'mydbinstance.cwyanwj3m6o5.ap-northeast-2.rds.amazonaws.com'
user_name = "oniun"
password = "wkatlf2ehd"
database_name = "oniun_db"

db = pymysql.connect(host=host_name, port=3306, user=user_name,
                     password=password, db=database_name, charset='utf8')

# %% [markdown]
# # Create Mysql DB & Tables

# %%
try:
    with db.cursor() as cursor:
        query = '''
            DROP DATABASE IF EXISTS app_review;
            CREATE DATABASE app_review DEFAULT CHARSET=utf8 COLLATE=utf8_bin;

            USE app_review;
        '''
        cursor.execute(query)
        db.commit()
finally:
    db.close()

# %% [markdown]
# # Insert CSV File to DB

# %%
reviews = pd.read_csv('./data/dataset.csv')

# %%
reviews.tail()
# Out:
#                app           date  rate  \
# 74044     오늘의 주요뉴스  2017년 11월 26일     5
# 74045     오늘의 주요뉴스  2017년 11월 26일     5
# 74046    롯데하이마트 소식   2016년 7월 23일     1
# 74047    롯데하이마트 소식    2016년 3월 4일     5
# 74048    C CHANNEL   2017년 7월 24일     3
#
#                                               review           user
# 74044                        뉴스 챙겨보기 귀찮았는데 챙겨 봐야겠어요~   geo hee kim
# 74045                                          좋네요^^            오도
# 74046                                        최악이네 최악           박재현
# 74047               하이마트소식지올라왔네^^@ 우와 오늘 처음 올라왔나 ^^@           이대희
# 74048  너무 랙많이 걸리고 한글은 아예 글이 깨져버리네요ㅜㅜ 그점만 개선 해주시면 별5개    방탄이 죠아 히모는

# %%
engine = create_engine('mysql+pymysql://oniun:'+"wkatlf2ehd"+'@mydbinstance.cwyanwj3m6o5.ap-northeast-2.rds.amazonaws.com:3306/app_review?charset=utf8mb4', encoding='utf-8')
conn = engine.connect()

# %%
reviews.to_sql(name='reviews', con=engine, if_exists='append', index=False)
# Out:
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x80' for column 'review' at row 4")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x98\\x82 \\xEC...' for column 'review' at row 90")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\xB4 \\xEF...' for column 'review' at row 165")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\xB4 \\xEF...' for column 'review' at row 201")
#   result = self._query(query)
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1366, "Incorrect string value: '\\xF0\\x9F\\x94\\xB4 \\xEF...' for column 'review' at row 257")
# ...

# %%
conn.close()

# %% [markdown]
# # SCRAPING WEB & INSERT INTO MYSQL

# %%
BASEURL = 'https://play.google.com/store/apps/category/'
category = ['FINANCE', 'SHOPPING', 'SPORTS', 'VIDEO_PLAYERS','MEDICAL', 'TRAVEL_AND_LOCAL', 'NEWS_AND_MAGEZINES']
ENDURL = '/collection/topselling_free'

GROSSING = 'https://play.google.com/store/apps/collection/topgrossing'
FREE = 'https://play.google.com/store/apps/collection/topselling_free'
PAID = 'https://play.google.com/store/apps/collection/topselling_paid'

target_url = list()
for item in category:
    target_url.append(BASEURL + str(item) + ENDURL)
    
target_url.append(GROSSING)
target_url.append(FREE)
target_url.append(PAID)

for url in target_url:
    print(url)
# Out:
# https://play.google.com/store/apps/category/FINANCE/collection/topselling_free
# https://play.google.com/store/apps/category/SHOPPING/collection/topselling_free
# https://play.google.com/store/apps/category/SPORTS/collection/topselling_free
# https://play.google.com/store/apps/category/VIDEO_PLAYERS/collection/topselling_free
# https://play.google.com/store/apps/category/MEDICAL/collection/topselling_free
# https://play.google.com/store/apps/category/TRAVEL_AND_LOCAL/collection/topselling_free
# https://play.google.com/store/apps/category/NEWS_AND_MAGEZINES/collection/topselling_free
# https://play.google.com/store/apps/collection/topgrossing
# https://play.google.com/store/apps/collection/topselling_free
# https://play.google.com/store/apps/collection/topselling_paid

# %% [markdown]
# ## mysql

# %%
def scrape_to_db(url):
    
    host_name = 'mydbinstance.cwyanwj3m6o5.ap-northeast-2.rds.amazonaws.com'
    user_name = "oniun"
    password = "wkatlf2ehd"
    database_name = "app_review"

    db = pymysql.connect(host=host_name, port=3306, user=user_name,
                     password=password, db=database_name, charset='utf8')
    
    cursor = db.cursor()
    
    # PhantomJS driver실행
    driver = webdriver.PhantomJS('PhantomJS')

    # google play page를 띄움
    driver.get(url)

    SCROLL_PAUSE_TIME = 3
    # Get Scroll Height
    last_height = driver.execute_script("return document.body.scrollHeight")
    
    while True:
        #scroll down to botton
        driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
        #wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        #calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

        page_source = driver.page_source

        soup = BeautifulSoup(page_source, 'html.parser')
        rank = soup.select('div.id-card-list.card-list.two-cards > div > div > div.details > a.title')
    
    for num, item in enumerate(rank):
        adders = str(item).split()[3]
        adder = re.search('/[\w/?=.]+', adders)
        add_url = adder.group()

        # app name
        name = re.search('(?<=...)[\w ]+', str(item.get_text()).strip(" "))
        get_app = name.group()

        res2 = requests.get('http://play.google.com' + str(add_url))
        soup2 = BeautifulSoup(res2.content, 'html.parser')

        users = soup2.select('div.review-info > span.author-name')
        dates = soup2.select('div.review-info > span.review-date')
        rates = soup2.select('div.review-info > div.review-info-star-rating')
        reviews = soup2.select('div > div.review-body.with-review-wrapper')

        for user, date, review, rate in zip(users, dates, reviews, rates):

            get_user = user.get_text()
            get_date = date.get_text()

            m = re.search('\d\w\w', str(rate))
            m2 = re.search('\d', m.group())
            
            get_rate = m2.group()
            get_review = review.get_text().strip(" ").rstrip('전체 리뷰')              
            
            emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F919-\U0001F924"  # emoticons+@
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
            
            get_review = emoji_pattern.sub("", get_review)
            
            sql = '''
                INSERT INTO app_review.reviews
                    (app, date, rate, review, user)
                VALUES
                    ("%s", "%s" , %d , "%s", "%s")
                ''' % (str(get_app), str(get_date), int(get_rate), str(get_review), str(get_user))
            
            cursor.execute(sql)
            db.commit()
    
    driver.close()
    driver.quit()
    
    return db.close()

# %%
# %%time
scrape_to_db('https://play.google.com/store/apps/category/COMICS/collection/topselling_free')
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <timed eval> in <module>()
#
# <ipython-input-87-4b83bf8826b7> in scrape_to_db(url)
#      83                 ''' % (str(get_app), str(get_date), int(get_rate), str(get_review), str(get_user))
#      84
# ---> 85             cursor.execute(sql)
#      86             db.commit()
#      87
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in execute(self, query, args)
#     164         query = self.mogrify(query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#     168         return result
#
# /usr/local/lib/python3.6/site-packages/pymysql/cursors.py in _query(self, q)
#     320         conn = self._get_db()
#     321         self._last_executed = q
# --> 322         conn.query(q)
#     323         self._do_get_result()
#     324         return self.rowcount
#
# ...

# %%
# %%time
for item in target_url:
    scrape_to_db(item)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-47-2c5dd402b534> in scrape_to_db(url)
#      63             m2 = re.search('\d', m.group())
#      64             get_rate = m2.group()
# ---> 65             rate_list.append(m2.group())
#      66
#      67             get_review = review.get_text().strip(" ").rstrip('전체 리뷰')
#
# NameError: name 'rate_list' is not defined

# %% [markdown]
# ### Bring Mysql Table as Pandas DataFrame

# %%
engine = create_engine('mysql+pymysql://oniun:'+"wkatlf2ehd"+'@mydbinstance.cwyanwj3m6o5.ap-northeast-2.rds.amazonaws.com:3306/app_review?charset=utf8mb4', encoding='utf-8')
conn = engine.connect()

# %%
reviews = pd.read_sql_table('reviews', conn)
reviews.tail()
# Out:
# Empty DataFrame
# Columns: [app, date, rate, review, user]
# Index: []

# %%
conn.close()
